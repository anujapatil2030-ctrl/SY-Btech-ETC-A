# %%
list1=['Anuja' ,'Sanjay' ,'Patil']
print(list1)
# Out:
# ['Anuja', 'Sanjay', 'Patil']

# %%
print(' '.join(list1))
# Out:
# Anuja Sanjay Patil

# %%
list1=['Anuja', 'Sanjay' ,'Patil']
print(list1[0:3])
# Out:
# ['Anuja', 'Sanjay', 'Patil']

# %%
list1=['Anuja', 'Sanjay' ,'Patil']
print(list1*3)
# Out:
# ['Anuja', 'Sanjay', 'Patil', 'Anuja', 'Sanjay', 'Patil', 'Anuja', 'Sanjay', 'Patil']

# %%
list1=['Anuja' ,'Sanjay' ,'Patil']
list2=["Entc","Department"]
print(list1+list2)
# Out:
# ['Anuja', 'Sanjay', 'Patil', 'Entc', 'Department']

# %%
no=[1,2,3,4,5]
no.append(10)
print(no)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
no=[1,2,3,4,5]
no.extend([10,8,5])
print(no)
# Out:
# [1, 2, 3, 4, 5, 10, 8, 5]

# %%
no1=[10,30]
no.extend(no1)
print(no)
# Out:
# [1, 2, 3, 4, 5, 10, 8, 5, 10, 30]

# %%
no.insert(8,3)
print(no)
# Out:
# [1, 2, 3, 3, 3, 4, 5, 10, 3, 8, 5, 10, 30]

# %%
print(no.index(3))
# Out:
# 2

# %%
no.pop()
print(no)
# Out:
# [1, 2, 3, 3, 3, 4, 5, 10, 3]

# %%
no.remove(2)
print(no)
# Out:
# [1, 3, 3, 3, 4, 5, 10, 3]

# %%
no.reverse()
print(no)
# Out:
# [3, 10, 5, 4, 3, 3, 3, 1]

# %%
n=no.copy()
print(n)
# Out:
# [3, 10, 5, 4, 3, 3, 3, 1]

# %%
no.clear()
print(no)
# Out:
# []

# %%
print(n.count(3))
# Out:
# 4

# %%
n.sort()
print(n)
# Out:
# [1, 3, 3, 3, 3, 4, 5, 10]

# %%
list=[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
print(list)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
name="Anuja Patil"
age="19"
print("name:",name)
print("age:",19)
# Out:
# name: Anuja Patil
# age: 19

# %%
print("anuja" ,"patil",sep=" - ")
# Out:
# anuja - patil

# %%
print("\nAnuja\nPatil\thello")
# Out:
# Anuja
# Patil	hello

# %%
name=input("Enter Name: ")
print("my name is ",name)
print(type(name))
# Out:
# Enter Name: anuja patil
# my name is  anuja patil
# <class 'str'>

# %%
a=int(input("enter no:"))
b=int(input("enter no:"))
print("sum:",a+b)
# Out:
# enter no12
# enter no3
# sum: 15

# %%
name='Anuja Patil'
age="19"
print("name:",name)
print("age:",19)
# Out:
# name: Anuja Patil
# age: 19

# %%
print("my name is" ,end=" ")
print("anuja")
# Out:
# my name is anuja

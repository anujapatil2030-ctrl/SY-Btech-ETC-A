# %%
a=5
b="5"
if a==b:
   print("true")
elif a===b:
   print("false")
# Out:
#   File "/tmp/ipykernel_768/3804613825.py", line 5
#     elif a===b:
#             ^
# SyntaxError: invalid syntax

# %%
age=int(input("Enter age:"))
citizen=input("\nEnter Citizenship:")
if age>=18:
  if citizen=="Indian":
    print("\nEligible for vote")
  else:
    print("\nNot a Indian Citizen")
else:
    print("\nNot Eligible>>>>>>>")
# Out:
# Enter age:12
#
# Enter Citizenship:Indian
#
# Not Eligible>>>>>>>

# %%
# Problem Statement:
# Develop a program that checks a user's eligibility for a bus pass. The program should prompt the user to enter their gender and their current state.
# A user is eligible for the bus pass only if they are female AND reside in the state of Maharashtra. Otherwise, the user is not eligible.

gender=input("\nEntewr Gender:")
State=input("Enter the State:")
if(gender=="female"):
   if(State=="Maharashtra"):
       print("Eligible for pass")
else:
   print("\nNot Eligible for BUs pass")
# Out:
# Entewr Gender:female
# Enter the State:Maharashtra
# Eligible for pass

# %%
a=5
b=9
if(a==5):
  sum=a+b
  mul=a*b
  print("\nSum:",sum)
  print("\nMUL:",mul)
else:
  a=a+1
  print("\nA:",a)
# Out:
# Sum: 14
#
# MUL: 45

# %%
marks=int(input("Enter:"))
if marks>80:
  print("\nGade A")
elif marks>70 and marks<=80:
  print("grade B")
elif marks>60 and marks<=70:
  print("Grade C")
else:
  print("Fail............")
# Out:
# Enter:81
#
# Gade A
